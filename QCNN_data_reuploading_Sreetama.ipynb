# %%
from jax import numpy as jnp
import jax
import optax
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, ConfusionMatrixDisplay, confusion_matrix, f1_score
from quantum_model import quantum_neural_network
import pennylane as qml
from sklearn.utils import gen_batches
import numpy as np
import tensorflow as tf
from keras.datasets import mnist
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction:
# ## Good morning,
# This is a simple tutorial on quantum neural network (QNN) with **data-reuploding techinque**. The neural net is trained on the MNIST dataset initially (the classification is binary, we select 0,1 classes), and then, we try to evaluate it also on a specific case of MedMNIST dataset, trying to be more realistic. Lastly, we implement a QCNN and we will see what happens with it.
# I recommend that I realized this work by combining some parts taken from other repos and adapted to my problem. I have some little doubts on few parts, but I will try to explain everything as I can.
#
# **Requirements:**
#
# **JAX** (for optimization, a specific version of numpy which suits with JAX functions and vectorization, but PyTorch is good anyway);
#
# **optax** (for optimizers to combine with JAX);
#
# **tensorflow and Keras** (to create the dataset and to use the *resize* method to downsample an image);
#
# **sklearn** (for accuracy_score in the test, gen_batches to generate batches of images and labels and to split train, val, test set);
#
# **Pennylane** (for quantum computing).

# %% [markdown]
# ## Dataset
#
# We define the **downsample** function to resize or downsample an image in terms of pixels. Obviosouly, I will not use (28x28) MNIST images on a quantum nn since the number of parameters inside rotational gates would increase too much. Rather, I will work with less pixels/features.
# **RandomMnist** is a class that create only train and validation sets from the training MNIST images inside Keras. Note that the images only come from the train tuple of Keras and we use sklearn to extract a fraction of them to create the smaller validation set. By doing so, we are sure that the images we would use in the TEST set wouldn't be contained in the previous train and val sets.
# Inside the class we declare the number of training images to work with, the specific classes, a shuffle to shuffle the dataset before extracting the vectors of Xs and ys, a resize integer to resize the image according to the vlaue we insert and a seed for reproducibility, i. e. using the same seed the train and validation set will be the same even though we apply the same method many times.

# %%
def down_sample(x_array: np.ndarray, size: int) -> np.ndarray:
    """
    Function that reduces size of the images array.
    Args:
        x_array (array): image array.
        size (int): new size to resize.
    Returns:
        new_array (array): resized image.
    """
    new_size = (size, size)
    x_array = np.reshape(x_array, (x_array.shape[0], x_array.shape[1], 1))
    new_array = tf.image.resize(x_array, new_size)
    return new_array.numpy()

class RandomMnist:
    """
    Class that creates a binary dataset out of Mnist after specifying the classes of images to deal with,
    based on Keras's API.
    The dataset created here is composed by train and validation set.
    Args:
        classes_of_items (list): classes of images;
        num_train_samples (int): number of training images;
        shuffle (bool): if True the images are shuffled before creating the dataset;
        resize (int): new image dimension (it must be lower than 28);
        my_seed (int): seed for reproducibility.
    Returns:
        X_train (array): set of training images of shape (num_images, new_shape*new_shape);
        y_train (array): set of training labels of shape (num_images,);
        X_val (array): set of validation images of shape (num_images, new_shape*new_shape);
        y_val (array): set of validation labels of shape (num_images,).
    Note that the number of validation data is 0.2*num_train_samples.
    """

    def __init__(self, classes_of_items: list, num_train_samples: int, shuffle: bool,
                 resize: int, my_seed: int) -> None:
        self.classes_of_items = classes_of_items
        self.num_train_samples = num_train_samples
        self.shuffle = shuffle
        self.resize = resize
        self.my_seed = my_seed

    def data(self) -> tuple:
        np.random.seed(self.my_seed)
        (train_X, train_y), (_, _) = mnist.load_data()
        X_train_filtered = train_X[np.isin(train_y, [self.classes_of_items[0], self.classes_of_items[1]])]
        y_train_filtered = train_y[np.isin(train_y, [self.classes_of_items[0], self.classes_of_items[1]])]

        X_train_filtered = X_train_filtered.astype('float16') / 255
        X_train_new = []
        if self.resize is not None and self.resize <= 28:
            for train in X_train_filtered:
                X_train_new.append(down_sample(train, self.resize))
        else:
            raise Exception("The new size must be smaller than the actual Mnist size that is 28!")
        # shuffle
        X_train_new = np.array(X_train_new)
        if self.shuffle:
            shuffled_indices = np.arange(len(X_train_new))
            np.random.shuffle(shuffled_indices)
            X_train_new = X_train_new[shuffled_indices]
            y_train_filtered = y_train_filtered[shuffled_indices]

        if self.num_train_samples is not None:
            num_samples_per_class = self.num_train_samples // len(self.classes_of_items)
            selected_indices = []
            for class_idx in self.classes_of_items:
                class_indices = np.where(y_train_filtered == class_idx)[0][:num_samples_per_class]
                selected_indices.extend(class_indices)
            X_train_ = X_train_new[selected_indices]
            y_train_filtered = y_train_filtered[selected_indices]
        else:
            raise RuntimeError("Insert number of images to form the train set.")

        X_train_ = X_train_.reshape(X_train_.shape[0], X_train_.shape[1] * X_train_.shape[2])
        X_train_final, X_val, y_train_final, y_val = train_test_split(
            X_train_, y_train_filtered, test_size=0.2, random_state=42)

        return (
            jnp.asarray(X_train_final),
            jnp.asarray(y_train_final),
            jnp.asarray(X_val),
            jnp.asarray(y_val),
        )

# %% [markdown]
# Note that the X_train, y_train, X_val and y_val are JAX arrays!

# %% [markdown]
# ## Quantum model
#
# Let's create the quantum model with my method, but I will be happy to learn a new method!
# The class contains a feature map circuit which is composed by a sequence of U3 gates to embed all the 64 features (we downscale the images to be (8x8) MNIST images) and a parameterized ansatz to learn 69 parameters each layer. Now we will display everything and we will understand how they work.

# %%
def convolutional_layer(weights, wires, skip_first_layer=True):
    """Adds a convolutional layer to a circuit.
    Args:
        weights (np.array): 1D array with 15 weights of the parametrized gates.
        wires (list[int]): Wires where the convolutional layer acts on.
        skip_first_layer (bool): Skips the first two U3 gates of a layer.
    """
    n_wires = len(wires)
    #assert n_wires >= 3, "this circuit is too small!"

    for p in [0, 1, 2]:
        for indx, w in enumerate(wires):
            if indx % 2 == p and indx < n_wires - 1:
                if indx % 2 == 0 and not skip_first_layer:
                    qml.U3(*weights[:3], wires=[w])
                    qml.U3(*weights[3:6], wires=[wires[indx + 1]])
                qml.IsingXX(weights[6], wires=[w, wires[indx + 1]])
                qml.IsingYY(weights[7], wires=[w, wires[indx + 1]])
                qml.IsingZZ(weights[8], wires=[w, wires[indx + 1]])
                qml.U3(*weights[9:12], wires=[w])
                qml.U3(*weights[12:], wires=[wires[indx + 1]])
                
def pooling_layer(weights, wires):
    """Adds a pooling layer to a circuit.
    Args:
        weights (np.array): Array with the weights of the conditional U3 gate.
        wires (list[int]): List of wires to apply the pooling layer on.
    """
    n_wires = len(wires)
    #assert len(wires) >= 1, "this circuit is too small!"

    for indx, w in enumerate(wires):
        if indx % 2 == 1 and indx < n_wires:
            m_outcome = qml.measure(w)
            qml.cond(m_outcome, qml.U3)(*weights, wires=wires[indx - 1])
            
def conv_and_pooling(kernel_weights, n_wires, skip_first_layer=True):
    """Apply both the convolutional and pooling layer."""
    convolutional_layer(kernel_weights[:15], n_wires, skip_first_layer=skip_first_layer)
    pooling_layer(kernel_weights[15:], n_wires)

# %%
num_wires = 8
device = qml.device("default.qubit", wires=num_wires)


@qml.qnode(device)
def conv_net(weights, features):
    """Define the QCNN circuit
    Args:
        weights (np.array): Parameters of the convolution and pool layers.
        last_layer_weights (np.array): Parameters of the last dense layer.
        features (np.array): Input data to be embedded using AmplitudEmbedding."""

    layers = weights.shape[1]
    wires = list(range(num_wires))

    # inputs the state input_state
    qml.AmplitudeEmbedding(features=features, wires=wires, pad_with=0.5)
    qml.Barrier(wires=wires, only_visual=True)

    # adds convolutional and pooling layers
    for j in range(layers):
        conv_and_pooling(weights[:, j], wires, skip_first_layer=(not j == 0))
        wires = wires[::2]
        qml.Barrier(wires=wires, only_visual=True)

    return qml.probs(wires=(0))


fig, ax = qml.draw_mpl(conv_net, decimals=1)(
    np.random.rand(18, 3), np.random.rand(2 ** num_wires)
)
plt.show()

# %% [markdown]
# We work with 8 **qubits**.
# Since we use always U3 gates we have 3 **param_per_gate**.
# We use also ControlledU3 gates for entanglement so we have one gate less with respect to the number of qubits -> **entangling_gate = qubits - 1**.

# %%
new_shape = 16
# Call the train and val sets
dataset = RandomMnist(classes_of_items=[0, 1], num_train_samples=500, shuffle=True, resize=new_shape, my_seed=999)
X_train, y_train, X_val, y_val = dataset.data()

# %%
jax.config.update('jax_platform_name', 'cpu')
jax.config.update("jax_enable_x64", True)

# %%
seed = 48
key = jax.random.PRNGKey(seed)
initial_params = jax.random.normal(key, shape=(18,3))
qml.draw_mpl(qnode=conv_net, style="sketch", decimals=1)(initial_params, X_train[0])
# Out:
# (<Figure size 3200x900 with 1 Axes>, <Axes: >)

# %% [markdown]
# As we can see, the parameters inside the ansatz are different in each layer, while features remain the same and are re-uploaded at each layer, whose number could be modified. The probabilities of getting a class 0 or 1 are measured after the circuit.

# %% [markdown]
# ## Useful functions before starting
#
# These functions are:
#
# **binary_crossentropy** which computes the output (i.e., a probability of getting the image 0 or 1) and loops through each output (which is an array of the form (number_of_elements, 2) since for each element I have 2 probabilities) and each true label (which is a vector of
# (number_of_elements, 1)) and applies binary cross-entropy formula;
#
# **optimizer_update** which updates the parameters after each iteration;
#
# **accuracy** which calculates the output, extracts the index of the largest probability and compares it to the corresponding true label.
#
# The **@jax.jit** should need for optimization.

# %%
@jax.jit
def binary_crossentropy_QCNN(x, y, theta):
    labels = jnp.array(y)
    pred = jnp.array(qnn(theta, x))
    loss = 0
    for l, p in zip(labels, pred):
        loss += l * (jnp.log(p[l])) + (1 - l) * jnp.log(1 - p[1 - l])
    return -jnp.sum(loss)/len(labels)

@jax.jit
def optimizer_update(opt_state, params, x, y):
    loss_value, grads = jax.value_and_grad(lambda theta: binary_crossentropy_QCNN(x, y, theta))(params)
    updates, opt_state = optimizer.update(grads, opt_state)
    params = optax.apply_updates(params, updates)
    return params, opt_state, loss_value

@jax.jit
def accuracy(x, y, theta):
    labels = jnp.array(y)
    predictions = jnp.array(qnn(theta, x))
    correct_predictions = jnp.sum(jnp.argmax(predictions, axis=1) == labels)
    return correct_predictions / len(labels)

# %% [markdown]
# ### Set some hyper-parameters

# %%
lr = 0.01
n_epochs = 200
batch_size = 32
cosine_decay_scheduler = optax.cosine_decay_schedule(0.1, decay_steps=n_epochs, alpha=0.95)
qnn_batched = jax.vmap(conv_net, (None, 0,)) # use vmap to apply quantum_nn function to a vector, it's typical in JAX.
qnn = jax.jit(qnn_batched)
optimizer = optax.adam(learning_rate=lr)

# %%
key = jax.random.split(key)[0]
params = jnp.copy(initial_params)
opt_state = optimizer.init(initial_params)

train_cost_epochs, train_acc_epochs, val_cost_epochs, val_acc_epochs = [], [], [], []
for epoch in range(1,n_epochs+1):
    idxs_dataset = jax.random.choice(key, jnp.array(list(range(X_train.shape[0]))), shape=(X_train.shape[0],), replace=False)
    key = jax.random.split(key)[0]
    for i in gen_batches(X_train.shape[0], batch_size): ## we use gen_batches to optimize and calculate the gradient during each batch
        idxs = idxs_dataset[i]
        params, opt_state, cost = optimizer_update(opt_state, params, X_train[idxs, :], y_train[idxs])
        cost = binary_crossentropy_QCNN(X_train, y_train, params,)
        val_cost = binary_crossentropy_QCNN(X_val, y_val, params,)
        train_acc = accuracy(X_train, y_train, params,) 
        val_acc = accuracy(X_val, y_val, params,)
    train_cost_epochs.append(cost)
    val_cost_epochs.append(val_cost)
    # Accuracy during training and validation
    train_acc_epochs.append(train_acc)
    val_acc_epochs.append(val_acc)
    print(f"Epoch: {epoch}, ---Train loss: ", cost, "---Val loss: ", val_cost, "---Train acc: ", train_acc,
          "---Val acc.: ", val_acc)
    optimal_params = params  # Optimal parameters after training saved here, ready to be used for predictions.
# Out:
# Epoch: 1, ---Train loss:  0.6185086 ---Val loss:  0.61657864 ---Train acc:  0.6625 ---Val acc.:  0.73
# Epoch: 2, ---Train loss:  0.58368313 ---Val loss:  0.5831402 ---Train acc:  0.915 ---Val acc.:  0.93
# Epoch: 3, ---Train loss:  0.55681366 ---Val loss:  0.5592513 ---Train acc:  0.9475 ---Val acc.:  0.98
# Epoch: 4, ---Train loss:  0.5403164 ---Val loss:  0.5463208 ---Train acc:  0.9775 ---Val acc.:  0.99
# Epoch: 5, ---Train loss:  0.52928054 ---Val loss:  0.53616846 ---Train acc:  0.9825 ---Val acc.:  0.99
# Epoch: 6, ---Train loss:  0.5166303 ---Val loss:  0.5241151 ---Train acc:  0.98 ---Val acc.:  0.99
# Epoch: 7, ---Train loss:  0.5027748 ---Val loss:  0.51595575 ---Train acc:  0.99 ---Val acc.:  1.0
# Epoch: 8, ---Train loss:  0.49033344 ---Val loss:  0.5030784 ---Train acc:  0.9925 ---Val acc.:  0.99
# Epoch: 9, ---Train loss:  0.4826361 ---Val loss:  0.49521813 ---Train acc:  0.995 ---Val acc.:  0.99
# Epoch: 10, ---Train loss:  0.47531164 ---Val loss:  0.48846108 ---Train acc:  0.9925 ---Val acc.:  0.99
# Epoch: 11, ---Train loss:  0.4663058 ---Val loss:  0.477918 ---Train acc:  0.995 ---Val acc.:  0.99
# Epoch: 12, ---Train loss:  0.4593899 ---Val loss:  0.4700236 ---Train acc:  0.9975 ---Val acc.:  0.99
# Epoch: 13, ---Train loss:  0.45447555 ---Val loss:  0.4645671 ---Train acc:  0.9975 ---Val acc.:  0.99
# Epoch: 14, ---Train loss:  0.45057428 ---Val loss:  0.4601193 ---Train acc:  0.9975 ---Val acc.:  0.99
# Epoch: 15, ---Train loss:  0.4464565 ---Val loss:  0.45633602 ---Train acc:  0.9975 ---Val acc.:  0.99
# Epoch: 16, ---Train loss:  0.4420201 ---Val loss:  0.45236582 ---Train acc:  0.9975 ---Val acc.:  0.99
# Epoch: 17, ---Train loss:  0.43692452 ---Val loss:  0.44722152 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 18, ---Train loss:  0.43157053 ---Val loss:  0.4423402 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 19, ---Train loss:  0.4267176 ---Val loss:  0.43800876 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 20, ---Train loss:  0.42263433 ---Val loss:  0.43457443 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 21, ---Train loss:  0.42078125 ---Val loss:  0.43286657 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 22, ---Train loss:  0.41672984 ---Val loss:  0.43046147 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 23, ---Train loss:  0.41442138 ---Val loss:  0.42858008 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 24, ---Train loss:  0.4119953 ---Val loss:  0.4267465 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 25, ---Train loss:  0.40950426 ---Val loss:  0.4248545 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 26, ---Train loss:  0.40725982 ---Val loss:  0.42335093 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 27, ---Train loss:  0.40498623 ---Val loss:  0.42158446 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 28, ---Train loss:  0.4029797 ---Val loss:  0.4201677 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 29, ---Train loss:  0.40172708 ---Val loss:  0.4187005 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 30, ---Train loss:  0.399507 ---Val loss:  0.4175468 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 31, ---Train loss:  0.39774424 ---Val loss:  0.41674456 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 32, ---Train loss:  0.39648792 ---Val loss:  0.41579357 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 33, ---Train loss:  0.3954702 ---Val loss:  0.41510382 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 34, ---Train loss:  0.39522117 ---Val loss:  0.41523978 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 35, ---Train loss:  0.3941068 ---Val loss:  0.4144382 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 36, ---Train loss:  0.3941279 ---Val loss:  0.41355482 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 37, ---Train loss:  0.39284068 ---Val loss:  0.4132496 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 38, ---Train loss:  0.3925442 ---Val loss:  0.41343465 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 39, ---Train loss:  0.3921247 ---Val loss:  0.41242984 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 40, ---Train loss:  0.39131376 ---Val loss:  0.41213027 ---Train acc:  1.0 ---Val acc.:  1.0
# Epoch: 41, ---Train loss:  0.39091608 ---Val loss:  0.41220114 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 42, ---Train loss:  0.3906728 ---Val loss:  0.41186336 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 43, ---Train loss:  0.38997406 ---Val loss:  0.41110927 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 44, ---Train loss:  0.38949147 ---Val loss:  0.41077873 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 45, ---Train loss:  0.3892188 ---Val loss:  0.41089582 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 46, ---Train loss:  0.38902703 ---Val loss:  0.4103093 ---Train acc:  1.0 ---Val acc.:  0.99
# Epoch: 47, ---Train loss:  0.3884784 ---Val loss:  0.41013485 ---Train acc:  0.9975 ---Val acc.:  0.99
# Epoch: 48, ---Train loss:  0.38883743 ---Val loss:  0.4110293 ---Train acc:  0.995 ---Val acc.:  0.99
# Epoch: 49, ---Train loss:  0.38788658 ---Val loss:  0.40995514 ---Train acc:  0.995 ---Val acc.:  0.99
# Epoch: 50, ---Train loss:  0.38748989 ---Val loss:  0.41009924 ---Train acc:  0.9925 ---Val acc.:  0.97
# Epoch: 51, ---Train loss:  0.38706172 ---Val loss:  0.40910795 ---Train acc:  0.9925 ---Val acc.:  0.98
# Epoch: 52, ---Train loss:  0.38714805 ---Val loss:  0.4092312 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 53, ---Train loss:  0.3889674 ---Val loss:  0.41149893 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 54, ---Train loss:  0.38632724 ---Val loss:  0.40890723 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 55, ---Train loss:  0.38579088 ---Val loss:  0.408153 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 56, ---Train loss:  0.38639683 ---Val loss:  0.40956163 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 57, ---Train loss:  0.38596115 ---Val loss:  0.4089038 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 58, ---Train loss:  0.38487273 ---Val loss:  0.4072348 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 59, ---Train loss:  0.38474485 ---Val loss:  0.40788788 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 60, ---Train loss:  0.38425717 ---Val loss:  0.40702832 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 61, ---Train loss:  0.3837673 ---Val loss:  0.4059115 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 62, ---Train loss:  0.38397428 ---Val loss:  0.40595278 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 63, ---Train loss:  0.38382372 ---Val loss:  0.40657404 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 64, ---Train loss:  0.38349235 ---Val loss:  0.40650517 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 65, ---Train loss:  0.38297382 ---Val loss:  0.40526235 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 66, ---Train loss:  0.3827964 ---Val loss:  0.40488905 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 67, ---Train loss:  0.38301608 ---Val loss:  0.40457618 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 68, ---Train loss:  0.3829854 ---Val loss:  0.40583605 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 69, ---Train loss:  0.381846 ---Val loss:  0.40457788 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 70, ---Train loss:  0.3815598 ---Val loss:  0.40367848 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 71, ---Train loss:  0.3815181 ---Val loss:  0.40410164 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 72, ---Train loss:  0.38323474 ---Val loss:  0.4046683 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 73, ---Train loss:  0.38152292 ---Val loss:  0.40394664 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 74, ---Train loss:  0.38131884 ---Val loss:  0.40387076 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 75, ---Train loss:  0.38101783 ---Val loss:  0.40320224 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 76, ---Train loss:  0.38082144 ---Val loss:  0.40306944 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 77, ---Train loss:  0.38159075 ---Val loss:  0.40337744 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 78, ---Train loss:  0.38079387 ---Val loss:  0.40271848 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 79, ---Train loss:  0.38075972 ---Val loss:  0.40309393 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 80, ---Train loss:  0.3805804 ---Val loss:  0.40357214 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 81, ---Train loss:  0.38289812 ---Val loss:  0.4063515 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 82, ---Train loss:  0.38040596 ---Val loss:  0.40300548 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 83, ---Train loss:  0.3803222 ---Val loss:  0.40326667 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 84, ---Train loss:  0.38026372 ---Val loss:  0.40305442 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 85, ---Train loss:  0.3800869 ---Val loss:  0.40244934 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 86, ---Train loss:  0.37998638 ---Val loss:  0.40302664 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 87, ---Train loss:  0.38035095 ---Val loss:  0.40354756 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 88, ---Train loss:  0.379985 ---Val loss:  0.40261826 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 89, ---Train loss:  0.3801162 ---Val loss:  0.40339628 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 90, ---Train loss:  0.3802086 ---Val loss:  0.40300933 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 91, ---Train loss:  0.38047567 ---Val loss:  0.40297794 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 92, ---Train loss:  0.3801154 ---Val loss:  0.40281862 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 93, ---Train loss:  0.37981582 ---Val loss:  0.40279907 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 94, ---Train loss:  0.37991926 ---Val loss:  0.40241024 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 95, ---Train loss:  0.3797756 ---Val loss:  0.4031826 ---Train acc:  0.99 ---Val acc.:  0.97
# Epoch: 96, ---Train loss:  0.3796856 ---Val loss:  0.40326536 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 97, ---Train loss:  0.3795769 ---Val loss:  0.40290126 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 98, ---Train loss:  0.37956813 ---Val loss:  0.4027915 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 99, ---Train loss:  0.37937185 ---Val loss:  0.40303573 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 100, ---Train loss:  0.37919107 ---Val loss:  0.40293372 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 101, ---Train loss:  0.37990806 ---Val loss:  0.40454516 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 102, ---Train loss:  0.3789328 ---Val loss:  0.40333846 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 103, ---Train loss:  0.37933365 ---Val loss:  0.40393475 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 104, ---Train loss:  0.3784657 ---Val loss:  0.40260044 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 105, ---Train loss:  0.37814617 ---Val loss:  0.40285906 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 106, ---Train loss:  0.3774044 ---Val loss:  0.4019916 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 107, ---Train loss:  0.37674364 ---Val loss:  0.40169907 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 108, ---Train loss:  0.37553555 ---Val loss:  0.40178084 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 109, ---Train loss:  0.37371463 ---Val loss:  0.4004029 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 110, ---Train loss:  0.37211254 ---Val loss:  0.39964756 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 111, ---Train loss:  0.3700142 ---Val loss:  0.39772174 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 112, ---Train loss:  0.36852592 ---Val loss:  0.3972506 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 113, ---Train loss:  0.36699682 ---Val loss:  0.39574862 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 114, ---Train loss:  0.36574072 ---Val loss:  0.39526314 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 115, ---Train loss:  0.36492378 ---Val loss:  0.3947602 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 116, ---Train loss:  0.3638775 ---Val loss:  0.39427078 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 117, ---Train loss:  0.36304945 ---Val loss:  0.39341915 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 118, ---Train loss:  0.36229494 ---Val loss:  0.39306575 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 119, ---Train loss:  0.3618119 ---Val loss:  0.3928258 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 120, ---Train loss:  0.36168438 ---Val loss:  0.39270666 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 121, ---Train loss:  0.36128393 ---Val loss:  0.3927314 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 122, ---Train loss:  0.36108047 ---Val loss:  0.3919652 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 123, ---Train loss:  0.361099 ---Val loss:  0.39268115 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 124, ---Train loss:  0.3605638 ---Val loss:  0.39227948 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 125, ---Train loss:  0.36134216 ---Val loss:  0.39267772 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 126, ---Train loss:  0.36051095 ---Val loss:  0.39248756 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 127, ---Train loss:  0.3601919 ---Val loss:  0.39196095 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 128, ---Train loss:  0.36007777 ---Val loss:  0.3918339 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 129, ---Train loss:  0.3602259 ---Val loss:  0.3919967 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 130, ---Train loss:  0.3604539 ---Val loss:  0.39275345 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 131, ---Train loss:  0.36009848 ---Val loss:  0.39191857 ---Train acc:  0.9875 ---Val acc.:  0.97
# Epoch: 132, ---Train loss:  0.36004412 ---Val loss:  0.39224765 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 133, ---Train loss:  0.36008984 ---Val loss:  0.39217228 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 134, ---Train loss:  0.36005327 ---Val loss:  0.39232382 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 135, ---Train loss:  0.35985088 ---Val loss:  0.39205885 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 136, ---Train loss:  0.35989258 ---Val loss:  0.39204982 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 137, ---Train loss:  0.35975647 ---Val loss:  0.39247993 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 138, ---Train loss:  0.35971418 ---Val loss:  0.3922381 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 139, ---Train loss:  0.35975063 ---Val loss:  0.39229044 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 140, ---Train loss:  0.36010626 ---Val loss:  0.39240646 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 141, ---Train loss:  0.36014098 ---Val loss:  0.39254823 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 142, ---Train loss:  0.35949504 ---Val loss:  0.39229977 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 143, ---Train loss:  0.35941944 ---Val loss:  0.39185363 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 144, ---Train loss:  0.3595485 ---Val loss:  0.3921555 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 145, ---Train loss:  0.35997418 ---Val loss:  0.39263797 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 146, ---Train loss:  0.36017457 ---Val loss:  0.39248785 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 147, ---Train loss:  0.3593733 ---Val loss:  0.39227718 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 148, ---Train loss:  0.3597583 ---Val loss:  0.39250758 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 149, ---Train loss:  0.3595911 ---Val loss:  0.39245474 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 150, ---Train loss:  0.35954264 ---Val loss:  0.39218208 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 151, ---Train loss:  0.35986316 ---Val loss:  0.39261496 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 152, ---Train loss:  0.35947734 ---Val loss:  0.39249492 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 153, ---Train loss:  0.35938188 ---Val loss:  0.3921966 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 154, ---Train loss:  0.35952452 ---Val loss:  0.39252484 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 155, ---Train loss:  0.3593765 ---Val loss:  0.39260298 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 156, ---Train loss:  0.36046135 ---Val loss:  0.393373 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 157, ---Train loss:  0.35966513 ---Val loss:  0.39227355 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 158, ---Train loss:  0.3601801 ---Val loss:  0.3933321 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 159, ---Train loss:  0.359555 ---Val loss:  0.3924177 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 160, ---Train loss:  0.35966387 ---Val loss:  0.3925301 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 161, ---Train loss:  0.3595632 ---Val loss:  0.39261812 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 162, ---Train loss:  0.35932788 ---Val loss:  0.39249137 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 163, ---Train loss:  0.35931456 ---Val loss:  0.39195013 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 164, ---Train loss:  0.3591887 ---Val loss:  0.39232266 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 165, ---Train loss:  0.3593667 ---Val loss:  0.3921613 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 166, ---Train loss:  0.36032423 ---Val loss:  0.3932463 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 167, ---Train loss:  0.35974288 ---Val loss:  0.3929296 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 168, ---Train loss:  0.35939917 ---Val loss:  0.39253047 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 169, ---Train loss:  0.35918212 ---Val loss:  0.39209807 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 170, ---Train loss:  0.35968807 ---Val loss:  0.39270577 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 171, ---Train loss:  0.35942978 ---Val loss:  0.39252067 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 172, ---Train loss:  0.35930946 ---Val loss:  0.39218915 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 173, ---Train loss:  0.35946572 ---Val loss:  0.39265597 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 174, ---Train loss:  0.3598512 ---Val loss:  0.3931946 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 175, ---Train loss:  0.35938153 ---Val loss:  0.3928344 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 176, ---Train loss:  0.36121985 ---Val loss:  0.39403224 ---Train acc:  0.98 ---Val acc.:  0.96
# Epoch: 177, ---Train loss:  0.35928622 ---Val loss:  0.39263624 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 178, ---Train loss:  0.3590887 ---Val loss:  0.39198697 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 179, ---Train loss:  0.35936144 ---Val loss:  0.39259556 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 180, ---Train loss:  0.35937893 ---Val loss:  0.39267525 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 181, ---Train loss:  0.35943922 ---Val loss:  0.39303508 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 182, ---Train loss:  0.35925457 ---Val loss:  0.39261428 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 183, ---Train loss:  0.35905692 ---Val loss:  0.39234573 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 184, ---Train loss:  0.35943022 ---Val loss:  0.39271548 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 185, ---Train loss:  0.35967916 ---Val loss:  0.39309365 ---Train acc:  0.98 ---Val acc.:  0.97
# Epoch: 186, ---Train loss:  0.3592731 ---Val loss:  0.39227462 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 187, ---Train loss:  0.36012903 ---Val loss:  0.39311802 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 188, ---Train loss:  0.36156493 ---Val loss:  0.39426973 ---Train acc:  0.98 ---Val acc.:  0.96
# Epoch: 189, ---Train loss:  0.3596035 ---Val loss:  0.39278603 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 190, ---Train loss:  0.35898933 ---Val loss:  0.39244437 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 191, ---Train loss:  0.35971123 ---Val loss:  0.39322722 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 192, ---Train loss:  0.3602001 ---Val loss:  0.39360306 ---Train acc:  0.98 ---Val acc.:  0.96
# Epoch: 193, ---Train loss:  0.35953116 ---Val loss:  0.39273277 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 194, ---Train loss:  0.3597124 ---Val loss:  0.39275435 ---Train acc:  0.98 ---Val acc.:  0.97
# Epoch: 195, ---Train loss:  0.35945827 ---Val loss:  0.39287752 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 196, ---Train loss:  0.3591741 ---Val loss:  0.39292133 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 197, ---Train loss:  0.3601215 ---Val loss:  0.39326108 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 198, ---Train loss:  0.35911056 ---Val loss:  0.39244092 ---Train acc:  0.985 ---Val acc.:  0.97
# Epoch: 199, ---Train loss:  0.3598254 ---Val loss:  0.3931288 ---Train acc:  0.9825 ---Val acc.:  0.97
# Epoch: 200, ---Train loss:  0.35936314 ---Val loss:  0.39246917 ---Train acc:  0.9825 ---Val acc.:  0.97

# %% [markdown]
# ## Plots

# %%
optimal_params
# Out:
# Array([[ 1.60067093,  1.20683646, -0.4423071 ],
#        [-0.38857325,  0.62231069, -1.1205552 ],
#        [-0.51102013,  0.09456453, -0.21383496],
#        [-1.82664648,  0.52392512,  0.89406374],
#        [-1.52757171,  1.91231052,  0.89540391],
#        [-0.18946901,  2.35273162,  0.33926702],
#        [-0.63885629,  1.04179357,  1.22384324],
#        [-1.72870253,  0.7606531 , -1.21337532],
#        [ 1.16617618,  0.65941529, -0.75541896],
#        [-1.73355179,  0.93621383,  1.81102151],
#        [-0.08192418, -1.35422195, -0.49909323],
#        [-0.13197318,  1.48948362,  1.9764241 ],
#        [-1.29195391, -0.31185276, -4.61199533],
#        [-0.40607374, -0.6356848 , -1.86710444],
#        [ 0.14260251,  1.148081  ,  0.46632158],
#        [-0.24442796,  4.49477554,  2.13600462],
#        [-1.4724818 ,  1.76165291,  0.71765536],
#        [-1.24772785,  0.26751533,  0.28480243]], dtype=float64)

# %%
plt.style.use("default")

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].plot(train_acc_epochs, label="Train acc", color="orange")
axs[0].plot(val_acc_epochs, label="Val acc", color="orangered", alpha=0.5, ls='--')
axs[0].set_xlabel("Epoch")
axs[1].plot(train_cost_epochs, label="Train loss", color="royalblue", mfc='white', markersize=6, lw=2)
axs[1].plot(val_cost_epochs, label="Val loss", color="darkblue", alpha=0.5, mfc='white', markersize=6, ls='--')
axs[1].set_xlabel("Epoch")
axs[1].legend(fontsize=20, framealpha=0, ncol=2, columnspacing=0.4, loc='upper left', bbox_to_anchor=(-0.1, 1.35))
axs[0].legend(fontsize=20, framealpha=0, ncol=2, columnspacing=0.4, loc='upper left', bbox_to_anchor=(-0.1, 1.35))
axs[0].set_xlabel(r'$Epoch$', fontsize=15)
axs[1].set_xlabel(r'$Epoch$', fontsize=15)
axs[0].tick_params(direction='in', length=8, width=2, top='on', right='on', labelsize=10)
axs[1].tick_params(direction='in', length=8, width=2, top='on', right='on', labelsize=10)
plt.tight_layout()

# %% [markdown]
# # Test the model
#
# We now create the TEST set by using the SECOND tuple of Keras: in this way we are 100% sure that the model will see new unseen images!

# %%
classes_of_items = [0,1]
num_samples = 300
num_samples_per_class = num_samples / 2

(_, _), (X_test, y_test) = mnist.load_data()

mask = np.isin(y_test, classes_of_items)
X_test_filtered = X_test[mask]
y_test_filtered = y_test[mask]

X_test_new = [down_sample(x_test, 8) for x_test in X_test_filtered]
X_test_final = np.array(X_test_new).reshape(len(X_test_new), -1) / 255.0
y_test_final = np.array(y_test_filtered)

selected_indices = []
for class_idx in classes_of_items:
    class_indices = np.where(y_test_filtered == class_idx)[0][:int(num_samples_per_class)]
    selected_indices.extend(class_indices)

# Shuffle selected indices
np.random.shuffle(selected_indices)


X_test_final = X_test_final[selected_indices]
y_test_final = y_test_final[selected_indices]
X_test_final = jnp.asarray(X_test_final)
y_test_final = jnp.asarray(y_test_final)

# %%
print("Number of 0s in the TEST set:", np.count_nonzero(y_test_final == 0))
print(" ")
print("Number of 1s in the TEST set:", np.count_nonzero(y_test_final == 1))
# Out:
# Number of 0s in the TEST set: 150
#
# Number of 1s in the TEST set: 150

# %%
def prediction(ytrue, qnn, opt_weights):
    ypred = jnp.array(qnn(opt_weights, X_test_final))  ## I used .T because I had a bug without it.
    estimated_lab = jnp.array([jnp.argmax(label) for label in ypred])
    return [np.round(accuracy_score(jnp.array(ytrue), estimated_lab),2), estimated_lab]

prediction(y_test_final, conv_net, optimal_params)[0]
# Out:
# 0.5

# %%
ConfusionMatrixDisplay(confusion_matrix(y_true=y_test_final, y_pred=prediction(y_test_final, conv_net, optimal_params)[1])).plot()

plt.tight_layout()

print("F1-score: ", f1_score(y_test_final, prediction(y_test_final, conv_net, optimal_params)[1]))
# Out:
# F1-score:  0.0

# %%
def plot_mnist_images(images, estimated_labels, num_images=100, num_cols=10):
    """
    Plot a grid of MNIST images.
    
    Args:
    - images (numpy.ndarray): Array of MNIST images
    - estimated_labels (numpy.ndarray): Array of estimated labels for the images
    - num_images (int): Number of images to plot (default is 100)
    - num_cols (int): Number of columns in the grid (default is 10)
    """
    num_rows = num_images // num_cols
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(14, 14))
    for i, ax in enumerate(axes.flat):
        ax.imshow(images[i].reshape((8, 8)), cmap='viridis')  # Corrected image shape
        label_color = 'green' if estimated_labels[i] == y_test_final[i] else 'red'
        ax.set_xlabel("Pred: " + str(estimated_labels[i]), color=label_color)  # Setting label color based on match
    plt.tight_layout()
    plt.show()

plot_mnist_images(X_test_final[:100], prediction(y_test_final, conv_net, optimal_params)[1][:100])

# %% [markdown]
# ## Thanks for reading and watching :)
